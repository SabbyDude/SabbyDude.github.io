# %% [markdown]
# Begin by installing the framework 'fer' using the command below

# %%
#  !pip install fer

# %% [markdown]
# 1.   Import FER and Matplotlib
# 2.   Upload the image
# 3.   Detect the emotion on image
# 4.   Print all the required details for image

# %%
from fer import FER
import matplotlib.pyplot as plt 
img = plt.imread("/content/happyface.jpg")
detector = FER(mtcnn=True)
print(detector.detect_emotions(img))
plt.imshow(img)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/compat/v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/layers/normalization.py:534: _colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# 31-07-2021:06:50:20,870 WARNING  [deprecation.py:336] From /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/layers/normalization.py:534: _colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# ...

# %%
emotion, score = detector.top_emotion(img)
print(emotion,score)
# Out:
# happy 1.0

# %% [markdown]
# Detecting all the other emotions from the given images

# %%
img = plt.imread("/content/angryface.jpeg")
detector = FER()
print(detector.top_emotion(img))
plt.imshow(img)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:2426: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# ('angry', 1.0)

# %%
img = plt.imread("/content/shocked-expression-260nw-379892053.jpg")
detector = FER()
print(detector.top_emotion(img))
plt.imshow(img)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:2426: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# ('surprise', 0.78)

# %%
img = plt.imread("/content/disgustface.jpg")
detector = FER()
emotion,score=(detector.top_emotion(img))
plt.imshow(img)
print(emotion,score)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:2426: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# angry 0.39

# %%
img = plt.imread("/content/fearface.jpg")
detector = FER()
emotion,score=(detector.top_emotion(img))
plt.imshow(img)
print(emotion,score)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:2426: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# surprise 0.45

# %%
img = plt.imread("/content/happyface.jpg")
detector = FER()
emotion,score=(detector.top_emotion(img))
plt.imshow(img)
print(emotion,score)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:2426: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# happy 1.0

# %%
img = plt.imread("/content/neutralface.jpg")
detector = FER()
emotion,score=(detector.top_emotion(img))
plt.imshow(img)
print(emotion,score)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:2426: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# neutral 0.94

# %%
img = plt.imread("/content/sadface.jpg")
detector = FER()
emotion,score=(detector.top_emotion(img))
plt.imshow(img)
print(emotion,score)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:2426: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# sad 0.41

# %%
img = plt.imread("/content/surprised face.jpg")
detector = FER()
emotion,score=(detector.top_emotion(img))
plt.imshow(img)
print(emotion,score)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:2426: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# surprise 0.98

# %%
img = plt.imread("/content/man-glasses-person-face-smile-happy-model-bart-human.jpg")
detector = FER()
emotion,score=(detector.top_emotion(img))
plt.imshow(img)
print(emotion,score)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:2426: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# happy 0.96

# %%
img = plt.imread("/content/emotions.jpg")
detector = FER()
emotion,score=(detector.top_emotion(img))
plt.imshow(img)
print(emotion,score)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:2426: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# happy 0.59

# %% [markdown]
# #Saving the result

# %%
import cv2
from fer import FER
detector = FER(mtcnn=True) 
image = cv2.imread("/content/man-glasses-person-face-smile-happy-model-bart-human.jpg")
result = detector.detect_emotions(image)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:2426: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '

# %%
bounding_box = result[0]["box"]
emotions = result[0]["emotions"]
# Bounding around face is drawn
cv2.rectangle(image,(bounding_box[0], bounding_box[1]),
(bounding_box[0] + bounding_box[2], bounding_box[1] + bounding_box[3]),(0, 155, 255), 2,)
# Out:
# array([[[ 20,  46,  83],
#         [ 20,  46,  83],
#         [ 20,  46,  83],
#         ...,
#         [  9,   4,   5],
#         [  9,   4,   5],
#         [  9,   4,   5]],
#
#        [[ 20,  46,  83],
#         [ 20,  46,  83],
#         [ 20,  46,  83],
#         ...,
#         [  9,   4,   5],
#         [  9,   4,   5],
#         [  9,   4,   5]],
#
#        [[ 20,  46,  82],
#         [ 20,  46,  82],
#         [ 20,  46,  82],
#         ...,
#         [  7,   4,   6],
#         [  7,   4,   6],
#         [  7,   4,   6]],
#
#        ...,
#
#        [[ 18,  90, 160],
#         [ 17,  90, 158],
#         [ 16,  90, 156],
#         ...,
#         [  6,  33,  47],
#         [  5,  34,  43],
#         [  5,  34,  41]],
#
#        [[ 20,  93, 161],
#         [ 19,  92, 160],
#         [ 18,  92, 158],
#         ...,
#         [  6,  33,  43],
#         [  5,  33,  40],
#         [  5,  34,  39]],
#
#        [[ 20,  93, 161],
#         [ 19,  93, 159],
#         [ 18,  92, 158],
# ...

# %%
for idx, (emotion, score) in enumerate(emotions.items()):
    color = (211, 211, 211) if score < 0.01 else (255, 0, 0)
    emotion_score = "{}: {}".format(
          emotion, "{:.2f}".format(score) if score > 0.01 else ""
        )
    cv2.putText(image,emotion_score,
            (bounding_box[0], bounding_box[1] + bounding_box[3] + 30 + idx * 15),cv2.FONT_HERSHEY_SIMPLEX,0.5,color,1,cv2.LINE_AA,)
cv2.imwrite("/content/emotions.jpg", image)
# Out:
# True

# %% [markdown]
# Testing the model for last time

# %%
img = plt.imread("/content/steve.jpg") #Add the image address here
detector = FER() #Call teh detect function
emotion,score=(detector.top_emotion(img)) #Save the emotion and how much of that emotion can be observed in two variables 
plt.imshow(img) #Plottng the image through matplotlib
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:2426: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '

# %% [markdown]
# #Result can be observed below

# %%
print("The main expression is {} and level is {}% respectively\n".format(emotion,score*100))
a=(detector.detect_emotions(img))
other=(a[0]['emotions'])
for i in other:
  print("Expression of {} is at level {:.2f}%".format(i,(other[i]*100)))
# Out:
# The main expression is happy and level is 89.0% respectively
#
# Expression of angry is at level 1.00%
# Expression of disgust is at level 0.00%
# Expression of fear is at level 1.00%
# Expression of happy is at level 89.00%
# Expression of sad is at level 3.00%
# Expression of surprise is at level 1.00%
# Expression of neutral is at level 5.00%
